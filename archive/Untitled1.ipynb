# %%
import json
import pandas as pd
json_file_path = "models/CNN1_aug/history.json"

# Read the existing JSON content
# with open(json_file_path, "r") as json_file:
#     existing_data = json.load(json_file)

# Modify the data (for example, add a new key-value pair)
# existing_data["new_key"] = "new_value"

# # Write the modified data back to the same file
# with open(json_file_path, "w") as json_file:
#     json.dump(existing_data, json_file, indent=4)  #

# %%
import os
folderpath = "models/CNN1_aug/" 
hist_json_file = folderpath + 'history.json' 
os.path.exists(hist_json_file)
# Out:
# True

# %%
hist_json_file
# Out:
# 'models/CNN1_aug/history.json'

# %%
import pandas as pd



# Read the JSON file into a DataFrame
df = pd.read_json(json_file_path)
df2 = pd.concat([df, df])
df2 = df2.reset_index(drop=True)

# Set the index to start from 1
df2.index = range(1, len(df2) + 1)

# %%
df2
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 1   1.202169  0.500421  1.414205      0.262695
# 2   0.923173  0.622159  1.750740      0.383789
# 3   0.779209  0.677555  1.085157      0.598633
# 4   0.723239  0.701465  0.743836      0.693359
# 5   0.696128  0.706011  0.691136      0.715820
# 6   0.653686  0.731268  0.674023      0.748047
# 7   0.615076  0.743054  0.632962      0.723633
# 8   0.568460  0.767469  0.591393      0.757812
# 9   0.542479  0.783970  0.686827      0.760742
# 10  0.500349  0.802155  0.507138      0.796875
# 11  0.481124  0.805186  0.701221      0.749023
# 12  0.471933  0.811079  0.528468      0.805664
# 13  0.453597  0.819161  0.605639      0.760742
# 14  0.433580  0.829769  0.414882      0.847656
# 15  0.402710  0.838862  0.508461      0.801758
# 16  0.398474  0.845092  0.427631      0.842773
# 17  0.396234  0.844587  0.942722      0.641602
# 18  1.202169  0.500421  1.414205      0.262695
# 19  0.923173  0.622159  1.750740      0.383789
# ...
